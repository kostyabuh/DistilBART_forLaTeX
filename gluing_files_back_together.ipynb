# %%
import pandas as pd

#index_col=[0] #потому что там какая-то артефактная колонка из csv образовалась
df_list = [pd.read_parquet(f"Downloads/TABLES_TO_TRANSLATE_FROM_JSON_3-8/markdown_table_{i}_translated.parquet") for i in range(10)]

# %%
df_list
# Out:
# [       text_id                                           markdown  \
#  0            0  For [[0]] and [[1]] such that \r\n[[2]]\r\nthe...
#  1            1  It suffices to look at the case [[0]]. Let [[1...
#  2            2  Since [[0]] are measurable, so are [[1]], and ...
#  3            3  No. Take [[0]] to be the indicator of [[1]]. T...
#  4            5  The absolute value is very simple:\r\n\r\n[[0]...
#  ...        ...                                                ...
#  92628    99511             [[0]]\r\n\r\nor [[1]] as above, [[2]].
#  92629    99512  If [[0]] is a finite group, then, as you noted...
#  92630    99513  Let [[0]] be a group and [[1]] irreducible rep...
#  92631    99515  Using the notation introduced above by Tsemo A...
#  92632    99516  If [[0]] generates [[1]], what can you say abo...
#
#                                              markdown_rus  \
#  0      Для [[0]] и [[1]] таких, что\r\n[[2]]\r\nнерав...
# ...

# %%
df = pd.concat(df_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 926327 entries, 0 to 92631
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   text_id       926327 non-null  int64
#  1   markdown      926327 non-null  object
#  2   markdown_rus  926327 non-null  object
#  3   formulae      926327 non-null  object
#  4   tags          926327 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 42.4+ MB

# %%
df.head(10)
# Out:
#    text_id                                           markdown  \
# 0        0  For [[0]] and [[1]] such that \r\n[[2]]\r\nthe...
# 1        1  It suffices to look at the case [[0]]. Let [[1...
# 2        2  Since [[0]] are measurable, so are [[1]], and ...
# 3        3  No. Take [[0]] to be the indicator of [[1]]. T...
# 4        5  The absolute value is very simple:\r\n\r\n[[0]...
# 5        6  Observe that [[0]]. Then the roots of the equa...
# 6        7  HINT:\r\n\r\ncis[[0]]\r\n\r\n[[1]]cis[[2]]\r\n...
# 7        8  If [[0]], it's known that for [[1]] a prime, [...
# 8       11  This is not true in general. The fact that [[0...
# 9       12  Exceptions will be of the following form:\r\n\...
#
#                                         markdown_rus  \
# 0  Для [[0]] и [[1]] таких, что\r\n[[2]]\r\nнерав...
# 1  Достаточно рассмотреть случай [[0]]. Пусть [[1...
# 2  Поскольку [[0]] измеримы, измеримы и [[1]], и\...
# 3  Нет. Предположим, что [[0]] является индикатор...
# ...

# %%
df = df.drop('markdown', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 926327 entries, 0 to 92631
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   text_id       926327 non-null  int64
#  1   markdown_rus  926327 non-null  object
#  2   formulae      926327 non-null  object
#  3   tags          926327 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 35.3+ MB

# %%
df.to_parquet('Downloads/TABLES_TO_TRANSLATE_FROM_JSON_3-8/texts_table_large_df.parquet')

# %%
df
# Out:
#        text_id                                       markdown_rus  \
# 0            0  Для [[0]] и [[1]] таких, что\r\n[[2]]\r\nнерав...
# 1            1  Достаточно рассмотреть случай [[0]]. Пусть [[1...
# 2            2  Поскольку [[0]] измеримы, измеримы и [[1]], и\...
# 3            3  Нет. Предположим, что [[0]] является индикатор...
# 4            5  Абсолютное значение очень просто:\r\n\r\n[[0]]...
# ...        ...                                                ...
# 92627  1026986  Еще один, понятный старшеклассникам и ниже.\r\...
# 92628  1026987  Пусть [[0]] — полиномиальные уравнения, которы...
# 92629  1026989  Это доказательство основано на происхождении (...
# 92630  1027011  > *счетно бесконечное* множество — это множест...
# 92631  1027014  > Как могут быть разные виды бесконечностей?\r...
#
#                                                 formulae  \
# 0      [$0\lt a\lt 1$, $b\gt 0$, $$1-\frac{\lfloor a\...
# ...
